# %%
# %env ANYWIDGET_HMR=1

import pyvuetify as v

w = v.Alert(type="success", children="This is a success alert - check it out!")
w
# Out:
# env: ANYWIDGET_HMR=1

# %%
w.type="warning"

# %%
w.title = "Toto"

# %%
w.children = "The alert message has been updated!"

# %%
w.color = "blue"

# %%
w.text = "Success!"

# %%
w.text = "Operation completed successfully."

# %%
w.border = True

# %%
import pyvuetify as v

# Nested widgets
alert = v.Alert(
    text="Alert with chips inside",
    children=[v.Chip(children="Tag 1", color="blue"), v.Chip(children="Tag 2", color="red")],
)
alert

# %%
alert2 = v.Alert(children=["toto", "tutu"], color="green")
alert2

# %%
alert.children = ["tutu"]

# %%
alert2

# %%
import pyvuetify as v

w = v.Alert(text="This is a success alert - check it out!", klass="ma-2", closable=True)
w.type = "success"
w

# %%
c = v.Chip(children="Toto", klass="ma-2", color="purple")
c

# %%
w.model_value = True
